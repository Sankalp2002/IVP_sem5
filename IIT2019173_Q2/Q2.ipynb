# %%
import PIL
from PIL import Image
loc1="horse.jpg"
loc2="saturn.png"
img1=Image.open(loc1)
img2=Image.open(loc2)
#display(img)
def p(img):
    planes=[]
    width,height=img.size
    for k in range(8):
        plane=PIL.Image.new(img.mode, img.size)
        for i in range(height):
            for j in range(width):
                r=img.getpixel((j,i))[0]
                num=r>>k
                if ((num&1)!=0):
                    plane.putpixel((j,i),(255,255,255))
                else:
                    plane.putpixel((j,i),(0,0,0))
        planes.append(plane)
    for i in range(8):
        display(planes[i])
p(img1)
p(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=165x218 at 0x1D9580A9AF0>
# <PIL.Image.Image image mode=RGB size=165x218 at 0x1D9580A9E80>
# <PIL.Image.Image image mode=RGB size=165x218 at 0x1D9580A9EB0>
# <PIL.Image.Image image mode=RGB size=165x218 at 0x1D958211DF0>
# <PIL.Image.Image image mode=RGB size=165x218 at 0x1D958211D90>
# <PIL.Image.Image image mode=RGB size=165x218 at 0x1D958211EE0>
# <PIL.Image.Image image mode=RGB size=165x218 at 0x1D958211EB0>
# <PIL.Image.Image image mode=RGB size=165x218 at 0x1D958211F10>
# <PIL.Image.Image image mode=RGBA size=354x447 at 0x1D9580A9EB0>
# <PIL.Image.Image image mode=RGBA size=354x447 at 0x1D9580A9EE0>
# <PIL.Image.Image image mode=RGBA size=354x447 at 0x1D9580A9E20>
# <PIL.Image.Image image mode=RGBA size=354x447 at 0x1D958211DC0>
# <PIL.Image.Image image mode=RGBA size=354x447 at 0x1D958211F40>
# <PIL.Image.Image image mode=RGBA size=354x447 at 0x1D958211E80>
# <PIL.Image.Image image mode=RGBA size=354x447 at 0x1D958211DF0>
# <PIL.Image.Image image mode=RGBA size=354x447 at 0x1D958211D90>
